# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
corpus = """I love Generative AI. I want to be a top 1% of 1% AI engineers in this world.
I believe ALLAH will make me as per expectation.
"""

# %%
documents = sent_tokenize(corpus)

# %%
print(documents)
# Out:
# ['I love Generative AI.', 'I want to be a top 1% of 1% AI engineers in this world.', 'I believe ALLAH will make me as per expectation.']

# %%
# corpus to word
from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)
words
# Out:
# ['I',
#  'love',
#  'Generative',
#  'AI',
#  '.',
#  'I',
#  'want',
#  'to',
#  'be',
#  'a',
#  'top',
#  '1',
#  '%',
#  'of',
#  '1',
#  '%',
#  'AI',
#  'engineers',
#  'in',
#  'this',
#  'world',
#  '.',
#  'I',
#  'believe',
#  'ALLAH',
#  'will',
#  'make',
#  'me',
#  'as',
#  'per',
#  'expectation',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['I', 'love', 'Generative', 'AI', '.']
# ['I', 'want', 'to', 'be', 'a', 'top', '1', '%', 'of', '1', '%', 'AI', 'engineers', 'in', 'this', 'world', '.']
# ['I', 'believe', 'ALLAH', 'will', 'make', 'me', 'as', 'per', 'expectation', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['I',
#  'love',
#  'Generative',
#  'AI',
#  '.',
#  'I',
#  'want',
#  'to',
#  'be',
#  'a',
#  'top',
#  '1',
#  '%',
#  'of',
#  '1',
#  '%',
#  'AI',
#  'engineers',
#  'in',
#  'this',
#  'world',
#  '.',
#  'I',
#  'believe',
#  'ALLAH',
#  'will',
#  'make',
#  'me',
#  'as',
#  'per',
#  'expectation',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tree_tokenizer = TreebankWordTokenizer()

# %%
tree_tokenizer.tokenize(corpus)
# Out:
# ['I',
#  'love',
#  'Generative',
#  'AI.',
#  'I',
#  'want',
#  'to',
#  'be',
#  'a',
#  'top',
#  '1',
#  '%',
#  'of',
#  '1',
#  '%',
#  'AI',
#  'engineers',
#  'in',
#  'this',
#  'world.',
#  'I',
#  'believe',
#  'ALLAH',
#  'will',
#  'make',
#  'me',
#  'as',
#  'per',
#  'expectation',
#  '.']
